# %% [markdown]
# # Pandas: Getting Started

# %% [markdown]
# **`Pandas`**: python library used for working with datasets.
#
# **2 Data Structures:** <br>
# **`1. Series`**: 1D array-like object containing a sequence of values (of the same type) and an associated array of data labels called its index.
#
# **`2. DataFrame`**: a form of 2D structured data, like a table with columns and rows.

# %%
# Import library and alias
import pandas as pd

# %% [markdown]
# ## Data Loading (Importing Data)

# %% [markdown]
# #### Data loading functions in pandas
# - **`read_csv`**
# - **`read_excel`**
# - **`read_json`**

# %%
# Loading csv data using Pandas
data_csv = pd.read_csv('C:/Users/AileahGotladera/OneDrive - GoTyme/Documents/Coaching/Customer-Churn-Records.csv', index_col = 0)
data_csv.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 2                112542.58       0         1                   3   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
#
#            Point Earned
# RowNumber
# 1                   464
# 2                   456
# 3                   377
# 4                   350
# 5                   425

# %% [markdown]
# ### Creating DataFrames
# #### Dictionaries

# %%
data_dict = {'odd_num': [7,5,3,1], 'letters': ['m', 'n', 'x', 'y']}

# Turn dictionary to a Dataframe
pd.DataFrame.from_dict(data_dict)

# %%
# Keys as index
pd.DataFrame.from_dict(data_dict, orient='index')
# Out:
#          0  1  2  3
# odd_num  7  5  3  1
# letters  m  n  x  y

# %%
# Specify column Names
pd.DataFrame.from_dict(data_dict, orient='index', columns = ['col1', 'col2', 'col3', 'col4'])
# Out:
#         col1 col2 col3 col4
# odd_num    7    5    3    1
# letters    m    n    x    y

# %%
#Creating a series
series_data = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
pd.Series(sd)
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %% [markdown]
# ##### Practice. Try it yourself!
# - Create a DF using the dictionary bills and make the keys as index and put column names as Bill Date and Status

# %%
bills = {'rent': [1, 'Paid'], 'wifi': [15, 'Not yet paid'], 'water': [12, 'Paid']}

...
# Out:
# Ellipsis

# %% [markdown]
# #### JSON Files
# - use `json` library to read JSON files.

# %%
# JSON String sample
data_file = '''{
    "firstName": "Hans",
    "lastName": "Diezmo",
    "hobby": "Sleeping",
    "age": 17
}'''

print(data_file)
# Out:
# {
#     "firstName": "Hans",
#     "lastName": "Diezmo",
#     "hobby": "Sleeping",
#     "age": 17
# }

# %%
import json

data_json = json.loads(data_file)
data_json
# Out:
# {'firstName': 'Hans', 'lastName': 'Diezmo', 'hobby': 'Sleeping', 'age': 17}

# %%
# Loading json string or file into a dictionary
json_df = pd.DataFrame.from_dict(data_json, orient='index', columns = ['Personal Details'])
json_df
# Out:
#           Personal Details
# firstName             Hans
# lastName            Diezmo
# hobby             Sleeping
# age                     17

# %% [markdown]
# ##### Practive. Try it yourself!
# - Load the JSON file *bills* and then transform it to DataFrame, name column properly

# %%
bills = '''{'rent': [1, 'Paid'], 'wifi': [15, 'Not yet paid']}'''

bills_json = ...

bills_df = 

bills_df = ...

# %% [markdown]
# ### Compressed File

# %%
# Run to know your current directory
# %cd
# Out:
# C:\Users\AileahGotladera

# %%
# %cd "C:/Users/AileahGotladera/OneDrive - GoTyme/Documents/Coaching"
# Out:
# C:\Users\AileahGotladera\OneDrive - GoTyme\Documents\Coaching

# %%
path = r"C:/Users/AileahGotladera/OneDrive - GoTyme/Documents/Coaching/Customer-Churn-Records - Zipped.zip"
df_zipped = pd.read_csv(path, compression="zip")
df_zipped
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0           101348.88       1         1                   2   DIAMOND
# 1           112542.58       0         1                   3   DIAMOND
# 2           113931.57       1         1                   3   DIAMOND
# 3            93826.63       0         0                   5      GOLD
# 4            79084.10       0         0                   5      GOLD
# ...               ...     ...       ...                 ...       ...
# 9995         96270.64       0         0                   1   DIAMOND
# 9996        101699.77       0         0                   5  PLATINUM
# 9997         42085.58       1         1                   3    SILVER
# 9998         92888.52       1         1                   2      GOLD
# 9999         38190.78       0         0                   3   DIAMOND
#
#       Point Earned
# 0              464
# 1              456
# 2              377
# 3              350
# 4              425
# ...            ...
# 9995           300
# 9996           771
# 9997           564
# 9998           339
# 9999           911
#
# [10000 rows x 18 columns]

# %% [markdown]
# ## Working with DataFrames

# %%
# %cd
# Out:
# C:\Users\AileahGotladera

# %%
# Loading data
data = pd.read_csv('C:/Users/AileahGotladera/OneDrive - GoTyme/Documents/Coaching/Customer-Churn-Records.csv', index_col = 0)

# %%
# View first 5 rows
data.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 2                112542.58       0         1                   3   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
#
#            Point Earned
# RowNumber
# 1                   464
# 2                   456
# 3                   377
# 4                   350
# 5                   425

# %% [markdown]
# #### DataFrame Indices
# - DF stores data in a row and column format.
# - DF index: a special kiund of column that helps identify the location of each row.
#     - Default index uses integers starting at 0 but can also set up customized indices such as *name*, *location*, etc.
#
# Note: Index Column can't have duplicate rows

# %%
data.index[:5]
# Out:
# Index([1, 2, 3, 4, 5], dtype='int64', name='RowNumber')

# %%
# Using another column as index using set_index method
data.set_index('CustomerId', inplace=True) #inplace: modifies the original DataFrame and returns None (Default: False)

# %%
data.head()
# Out:
#              Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# CustomerId
# 15634602    Hargrave          619    France  Female   42       2       0.00
# 15647311        Hill          608     Spain  Female   41       1   83807.86
# 15619304        Onio          502    France  Female   42       8  159660.80
# 15701354        Boni          699    France  Female   39       1       0.00
# 15737888    Mitchell          850     Spain  Female   43       2  125510.82
#
#             NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# CustomerId
# 15634602                1          1               1        101348.88       1
# 15647311                1          0               1        112542.58       0
# 15619304                3          1               0        113931.57       1
# 15701354                2          0               0         93826.63       0
# 15737888                1          1               1         79084.10       0
#
#             Complain  Satisfaction Score Card Type  Point Earned
# CustomerId
# 15634602           1                   2   DIAMOND           464
# 15647311           1                   3   DIAMOND           456
# 15619304           1                   3   DIAMOND           377
# 15701354           0                   5      GOLD           350
# 15737888           0                   5      GOLD           425

# %%
# Updated index
data.index[:5]
# Out:
# Index([15634602, 15647311, 15619304, 15701354, 15737888], dtype='int64', name='CustomerId')

# %%
# Reset index back to default integer counts and column made index will become a column againd
data.reset_index(inplace=True)
data.head(2)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure   Balance  \
# 0    15634602  Hargrave          619    France  Female   42       2      0.00
# 1    15647311      Hill          608     Spain  Female   41       1  83807.86
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
#
#    Complain  Satisfaction Score Card Type  Point Earned
# 0         1                   2   DIAMOND           464
# 1         1                   3   DIAMOND           456

# %% [markdown]
# ##### Practice. Try it yourself!
# - Set leter as the index, then call the index. Then reset the index

# %%
data = {
    "letter": ["a", "b", "c", "d"],
    "number": [3, 2, 1, 0],
    "location": ["east", "east", "east", "west"],
}
df = pd.DataFrame.from_dict(data)

# Set new index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 6
#       1 data = {
#       2     "letter": ["a", "b", "c", "d"],
#       3     "number": [3, 2, 1, 0],
#       4     "location": ["east", "east", "east", "west"],
#       5 }
# ----> 6 df = pd.DataFrame.from_dict(data)
#       8 # Set new index
#
# NameError: name 'pd' is not defined

# %%
# Reset index

# %% [markdown]
# ### Inspecting DataFrames
# - Pandas has many ways to inspeact a DF, but we're only going to look at 3: `shape`, `info`, `head`

# %%
# Shape: understanding the dimensionality of the DF
data_csv.shape
# Out:
# (10000, 17)

# %%
# Info: general idea of what a DF contains
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   Surname             10000 non-null  object
#  2   CreditScore         10000 non-null  int64
#  3   Geography           10000 non-null  object
#  4   Gender              10000 non-null  object
#  5   Age                 10000 non-null  int64
#  6   Tenure              10000 non-null  int64
#  7   Balance             10000 non-null  float64
#  8   NumOfProducts       10000 non-null  int64
#  9   HasCrCard           10000 non-null  int64
#  10  IsActiveMember      10000 non-null  int64
#  11  EstimatedSalary     10000 non-null  float64
#  12  Exited              10000 non-null  int64
#  13  Complain            10000 non-null  int64
#  14  Satisfaction Score  10000 non-null  int64
#  15  Card Type           10000 non-null  object
#  16  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(11), object(4)
# memory usage: 1.4+ MB

# %%
# Head: look at the first 5 rows (default) or more/less of a DF
data_csv.head(1)
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
#
#            Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# RowNumber
# 1              0.0              1          1               1        101348.88
#
#            Exited  Complain  Satisfaction Score Card Type  Point Earned
# RowNumber
# 1               1         1                   2   DIAMOND           464

# %% [markdown]
# ### Sorting
# - DF is **ordered**
# - Pandas has 2 sorting methods:
#     - `sort_values`
#     - `sort_index`

# %%
data_csv.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 2                112542.58       0         1                   3   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
#
#            Point Earned
# RowNumber
# 1                   464
# 2                   456
# 3                   377
# 4                   350
# 5                   425

# %%
# Sort the whole DF by values of a column
data_csv.sort_values('Age').head()
# Out:
#            CustomerId      Surname  CreditScore Geography  Gender  Age  \
# RowNumber
# 3513         15657779       Boylan          806     Spain    Male   18
# 1679         15569178    Kharlamov          570    France  Female   18
# 3518         15757821      Burgess          771     Spain    Male   18
# 9521         15673180  Onyekaozulu          727   Germany  Female   18
# 2022         15795519     Vasiliev          716   Germany  Female   18
#
#            Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 3513            3       0.00              2          1               1
# 1679            4   82767.42              1          1               0
# 3518            1       0.00              2          0               0
# 9521            2   93816.70              2          1               0
# 2022            3  128743.80              1          0               0
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 3513              86994.54       0         0                   2      GOLD
# 1679              71811.90       0         0                   5    SILVER
# 3518              41542.95       0         0                   1      GOLD
# 9521             126172.11       0         0                   1   DIAMOND
# 2022             197322.13       0         0                   5      GOLD
#
#            Point Earned
# RowNumber
# 3513                768
# 1679                507
# 3518                371
# 9521                523
# 2022                243

# %%
data_csv.sort_values('Age').reset_index().head()
# Out:
#    RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0       3513    15657779       Boylan          806     Spain    Male   18
# 1       1679    15569178    Kharlamov          570    France  Female   18
# 2       3518    15757821      Burgess          771     Spain    Male   18
# 3       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 4       2022    15795519     Vasiliev          716   Germany  Female   18
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       3       0.00              2          1               1
# 1       4   82767.42              1          1               0
# 2       1       0.00              2          0               0
# 3       2   93816.70              2          1               0
# 4       3  128743.80              1          0               0
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0         86994.54       0         0                   2      GOLD
# 1         71811.90       0         0                   5    SILVER
# 2         41542.95       0         0                   1      GOLD
# 3        126172.11       0         0                   1   DIAMOND
# 4        197322.13       0         0                   5      GOLD
#
#    Point Earned
# 0           768
# 1           507
# 2           371
# 3           523
# 4           243

# %%
# Sort DF by its index
data_csv.set_index('Tenure').sort_index().head()
# Out:
#         CustomerId        Surname  CreditScore Geography  Gender  Age  \
# Tenure
# 0         15691287           Ford          675   Germany  Female   33
# 0         15587647         Browne          850   Germany  Female   66
# 0         15732235     Kuykendall          662    France    Male   64
# 0         15758750  Iweobiegbunam          564    France    Male   31
# 0         15611767            Mai          624   Germany  Female   52
#
#           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Tenure
# 0       141816.25              1          1               0         64815.05
# 0       127120.62              1          0               1        118929.64
# 0        98848.19              1          0               1         42730.12
# 0       110527.17              1          1               1         87060.77
# 0       133723.43              1          0               0          4859.59
#
#         Exited  Complain  Satisfaction Score Card Type  Point Earned
# Tenure
# 0            1         1                   4      GOLD           290
# 0            1         1                   1  PLATINUM           617
# 0            0         0                   1    SILVER           676
# 0            0         0                   2      GOLD           752
# 0            1         1                   5    SILVER           500

# %% [markdown]
# #### Working with Columns
# - It can be handy to duplicate a column:
#     - Dropped data points or erase empty cells and still preserve the original column.

# %% [markdown]
# ### Creating New Column
#
# df["revenue"] = df["price"] * df["quantity"] * (1 - df["discount"])

# %%
# Create new column
data_csv['age_onboarded'] = data_csv['Age'] - data_csv['Tenure']
data_csv.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 2                112542.58       0         1                   3   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
#
#            Point Earned  age_onboarded
# RowNumber
# 1                   464             40
# 2                   456             40
# 3                   377             34
# 4                   350             38
# 5                   425             41

# %% [markdown]
# ### Dropping Columns
# - `drop` method

# %%
data_csv2 = data_csv.drop('age_onboarded',  axis='columns') # set axis to "index" if want to drp rows
data_csv2.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 2                112542.58       0         1                   3   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
#
#            Point Earned
# RowNumber
# 1                   464
# 2                   456
# 3                   377
# 4                   350
# 5                   425

# %%
data_csv2 = data_csv2.drop(2, axis="index")
data_csv2.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
# 6            15574012       Chu          645     Spain    Male   44       8
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
# 6          113755.78              2          1               0
#
#            EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# RowNumber
# 1                101348.88       1         1                   2   DIAMOND
# 3                113931.57       1         1                   3   DIAMOND
# 4                 93826.63       0         0                   5      GOLD
# 5                 79084.10       0         0                   5      GOLD
# 6                149756.71       1         1                   5   DIAMOND
#
#            Point Earned
# RowNumber
# 1                   464
# 3                   377
# 4                   350
# 5                   425
# 6                   484

# %% [markdown]
# ### Recasting Data

# %%
print(data_csv.info())
new_data_csv = data_csv.astype('str')
print(new_data_csv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   Surname             10000 non-null  object
#  2   CreditScore         10000 non-null  int64
#  3   Geography           10000 non-null  object
#  4   Gender              10000 non-null  object
#  5   Age                 10000 non-null  int64
#  6   Tenure              10000 non-null  int64
#  7   Balance             10000 non-null  float64
#  8   NumOfProducts       10000 non-null  int64
#  9   HasCrCard           10000 non-null  int64
#  10  IsActiveMember      10000 non-null  int64
#  11  EstimatedSalary     10000 non-null  float64
#  12  Exited              10000 non-null  int64
#  13  Complain            10000 non-null  int64
#  14  Satisfaction Score  10000 non-null  int64
#  15  Card Type           10000 non-null  object
#  16  Point Earned        10000 non-null  int64
#  17  age_onboarded       10000 non-null  int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 1.7+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  object
#  1   Surname             10000 non-null  object
#  2   CreditScore         10000 non-null  object
#  3   Geography           10000 non-null  object
#  4   Gender              10000 non-null  object
#  5   Age                 10000 non-null  object
#  6   Tenure              10000 non-null  object
#  7   Balance             10000 non-null  object
#  8   NumOfProducts       10000 non-null  object
#  9   HasCrCard           10000 non-null  object
#  10  IsActiveMember      10000 non-null  object
#  11  EstimatedSalary     10000 non-null  object
#  12  Exited              10000 non-null  object
#  13  Complain            10000 non-null  object
#  14  Satisfaction Score  10000 non-null  object
#  15  Card Type           10000 non-null  object
#  16  Point Earned        10000 non-null  object
#  17  age_onboarded       10000 non-null  object
# dtypes: object(18)
# memory usage: 1.7+ MB
# None

# %%
# Recast individual column
data_csv['Point Earned'] = data_csv['Point Earned'].astype(float)
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 1 to 10000
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerId          10000 non-null  int64
#  1   Surname             10000 non-null  object
#  2   CreditScore         10000 non-null  int64
#  3   Geography           10000 non-null  object
#  4   Gender              10000 non-null  object
#  5   Age                 10000 non-null  int64
#  6   Tenure              10000 non-null  int64
#  7   Balance             10000 non-null  float64
#  8   NumOfProducts       10000 non-null  int64
#  9   HasCrCard           10000 non-null  int64
#  10  IsActiveMember      10000 non-null  int64
#  11  EstimatedSalary     10000 non-null  float64
#  12  Exited              10000 non-null  int64
#  13  Complain            10000 non-null  int64
#  14  Satisfaction Score  10000 non-null  int64
#  15  Card Type           10000 non-null  object
#  16  Point Earned        10000 non-null  float64
#  17  age_onboarded       10000 non-null  int64
# dtypes: float64(3), int64(11), object(4)
# memory usage: 1.7+ MB

# %% [markdown]
# - Fix type to `Date type`: **pd.to_datetime(df["column"])**

# %% [markdown]
# ### Access a substring in a Series
# - `.str` attribute: index each string by providing `start:stop:step` (start position: inclusive, stop position exclusive)

# %%
data_csv.Geography.str[0:3:2]
# Out:
# RowNumber
# 1        Fa
# 2        Sa
# 3        Fa
# 4        Fa
# 5        Sa
#          ..
# 9996     Fa
# 9997     Fa
# 9998     Fa
# 9999     Gr
# 10000    Fa
# Name: Geography, Length: 10000, dtype: object

# %% [markdown]
# ### Renaming a Column

# %%
data_csv.rename(columns={'Card Type': 'card_type','Satisfaction Score': 'satisfaction' }, inplace=True)

# %% [markdown]
# ### Replacing String Characters
# - `replace` method (what to replace, replacement)

# %%
data_csv.card_type = data_csv.card_type.str.replace('GOLD', 'Classic')
data_csv.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  satisfaction card_type  \
# RowNumber
# 1                101348.88       1         1             2   DIAMOND
# 2                112542.58       0         1             3   DIAMOND
# 3                113931.57       1         1             3   DIAMOND
# 4                 93826.63       0         0             5  Platinum
# 5                 79084.10       0         0             5  Platinum
#
#            Point Earned  age_onboarded
# RowNumber
# 1                 464.0             40
# 2                 456.0             40
# 3                 377.0             34
# 4                 350.0             38
# 5                 425.0             41

# %%
data_csv_char = data_csv.copy()
data_csv_char['CustomerId'] = data_csv_char.CustomerId.astype(str).str.split('15').str[1]

data_csv_char.head(3)
# Out:
#   CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0     634602  Hargrave          619    France  Female   42       2       0.00
# 1     647311      Hill          608     Spain  Female   41       1   83807.86
# 2     619304      Onio          502    France  Female   42       8  159660.80
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
#
#    Complain  satisfaction card_type  Point Earned  age_onboarded
# 0         1             2   DIAMOND         464.0             40
# 1         1             3   DIAMOND         456.0             40
# 2         1             3   DIAMOND         377.0             34

# %% [markdown]
# ### Determine the unique values in a column

# %%
data_csv.card_type.unique()
# Out:
# array(['DIAMOND', 'Platinum', 'SILVER', 'PLATINUM'], dtype=object)

# %%
data_csv.card_type.nunique()
# Out:
# 4

# %% [markdown]
# ### Replacing Column Values
# - `replace()`

# %%
data_csv.card_type.replace('Platinum', 'GOLD', inplace=True)
data_csv.head()
# Out:
# C:\Users\AileahGotladera\AppData\Local\Temp\ipykernel_35428\2709744102.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_csv.card_type.replace('Platinum', 'GOLD', inplace=True)
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited  Complain  satisfaction card_type  \
# RowNumber
# 1                101348.88       1         1             2   DIAMOND
# 2                112542.58       0         1             3   DIAMOND
# 3                113931.57       1         1             3   DIAMOND
# 4                 93826.63       0         0             5      GOLD
# 5                 79084.10       0         0             5      GOLD
#
#            Point Earned  age_onboarded
# RowNumber
# 1                 464.0             40
# 2                 456.0             40
# 3                 377.0             34
# 4                 350.0             38
# 5                 425.0             41

# %%
data_csv.card_type.unique()
# Out:
# array(['DIAMOND', 'GOLD', 'SILVER', 'PLATINUM'], dtype=object)

# %% [markdown]
# ### Concatenate

# %%
import pandas as pd

# 2 DF
df1 = pd.DataFrame({
    'id': [1, 2, 3],
    'name': ['Alice', 'Bob', 'Charlie']
})

df2 = pd.DataFrame({
    'id': [4, 5, 6],
    'name': ['David', 'Ella', 'Frank']
})

# Concatenating DFs
result = pd.concat([df1, df2])
result.reset_index(drop=True)
# Out:
#    id     name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5     Ella
# 5   6    Frank

# %% [markdown]
# ### Saving a DF as a CSV

# %%
data_csv.reset_index(drop=True, inplace=True)
data_csv.head(1)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  Balance  \
# 0    15634602  Hargrave          619    France  Female   42       2      0.0
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
#
#    Complain  satisfaction card_type  Point Earned  age_onboarded
# 0         1             2   DIAMOND         464.0             40

# %%
data_csv.to_csv('df_tocsv.csv', index=False)

# %% [markdown]
# ## Exercise

# %% [markdown]
# ### Load and Inspect
# - Load orders.csv
# - Inspect the csv file, its contents, column details, shape

# %% [markdown]
# ### Index and Sort
# - Set order_id as index, then reset. Sort by city ascending, channel descending.

# %% [markdown]
# ### Column Ops (Add, Drop, Rename, Replace)
# - Add full_name = first + " " + last.
# - Drop middle.
# - Rename product_code -> sku.
# - Replace MNL -> Manila in city

# %% [markdown]
# ### String Basics (Substring and Char Replace)
# - Create dept = first 3 characters of sku.
# - Create domain from email (text after @).
# -  Replace _ with space in product_name

# %% [markdown]
# ### Unique Value and Counts
# - Show all unique city values, and print the count of unique sku prefixes (dept).

# %% [markdown]
# ### Creating your own DF.
# - Create two small DataFrames (one from a dictionary, one from JSON) with matching columns; concatenate to the original and save as `my_dataframe.csv`

# %% [markdown]
# ---
# *End of Code*
